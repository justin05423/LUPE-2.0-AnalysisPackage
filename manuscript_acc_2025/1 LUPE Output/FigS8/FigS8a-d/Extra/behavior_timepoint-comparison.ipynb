# %% [markdown]
# # Behavior Analysis: Comparison of Timepoints

# %% [markdown]
# Press SHIFT + ENTER to run code

# %% [markdown]
# ### USER INPUT!

# %%
## Define project
project_name = 'project_ACC_Study3_FormalinMorphine'

# Select group and condition, see meta.py to see how you previously defined it for your project
selected_groups = ['Male','Female']
selected_conditions = ['Group1_0mgkg','Group2_0.5mgkg','Group3_1.0mgkg','Group4_5mgkg','Group5_10mgkg']

# %% [markdown]
# ### Main Code: Create Individual CSVs for Timepoint Comparisons (Fraction Time in Behavior; Bouts/Min; Mean Bout Duration)

# %%
### Continue to Press SHIFT + ENTER to run code ###

# Prompt user for input
num_timepoints = int(input("Enter the number of time ranges you want to compare (e.g., 2, 3, etc.): "))
time_ranges = [] # Enter the time ranges IN MINUTES (e.g., 0-10 for 0 to 10 minutes, then 11-30 for remaining 11-30 minutes)

for i in range(num_timepoints):
    time_range = input(f"Time range {i + 1}: ")
    try:
        start_min, end_min = map(int, time_range.split('-'))
        if start_min >= end_min:
            print(f"Error: Start time ({start_min}) must be less than end time ({end_min}).")
            exit()
        start_sec, end_sec = start_min * 60, end_min * 60
        time_ranges.append((start_sec, end_sec))
    except ValueError:
        print("Invalid input format. Please enter the time range as 'start-end' (e.g., 0-10).")
        exit()

# %% [markdown]
# ### Individual File Comparisons

# %%
import os
import pandas as pd

# Validate the time ranges
if len(time_ranges) < 2:
    print("Error: At least two time ranges are required for comparison.")
    exit()

bins = [start for start, end in time_ranges] + [time_ranges[-1][1]]
time_labels = [f"{start//60}-{end//60} min" for start, end in time_ranges]

# Directory containing the per-second CSV files
input_dir = f'../processed_dataset/{project_name}/figures/behaviors_csv_raw-classification/seconds'

# Directory to save the analysis results
analysis_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison'
os.makedirs(analysis_dir, exist_ok=True)

def calculate_behavior_metrics(data, frame_rate=60):
    metrics = {}
    unique_behaviors = data['behavior'].unique()

    for behavior in unique_behaviors:
        behavior_data = data[data['behavior'] == behavior]
        
        fraction_time = len(behavior_data) / len(data)

        bout_starts = (behavior_data.index.to_series().diff() > 1).cumsum()
        bouts = behavior_data.groupby(bout_starts)

        bouts_per_minute = len(bouts) / (len(data) / frame_rate / 60)

        mean_bout_duration = bouts.size().mean() / frame_rate

        metrics[behavior] = {
            'Fraction Time': fraction_time,
            'Bouts per Minute': bouts_per_minute,
            'Mean Bout Duration (s)': mean_bout_duration
        }
    return metrics

# Processing each file
for file_name in os.listdir(input_dir):
    if file_name.endswith('.csv'):
        
        file_path = os.path.join(input_dir, file_name)
        df = pd.read_csv(file_path)
        
        max_time = df['time_seconds'].max()
        
        bins = [start for start, end in time_ranges] + [time_ranges[-1][1]]
        if max_time < bins[-1]:
            print(f"Warning: Maximum time ({max_time}s) in {file_name} is less than the final bin end ({bins[-1]}s).")
            bins[-1] = max_time

        print(f"Processing file: {file_name}")
        print(f"Bins: {bins}")
        print(f"Time Labels: {time_labels}")
        
        try:
            df['time_group'] = pd.cut(df['time_seconds'], 
                                      bins=bins,
                                      labels=time_labels,
                                      right=False)
        except ValueError as e:
            print(f"Error in pd.cut for file {file_name}: {e}")
            continue 
        
        # Analyzing behaviors for each time group
        all_metrics = []
        for time_group, group_data in df.groupby('time_group', observed=False):
            if not group_data.empty:
                metrics = calculate_behavior_metrics(group_data)
                for behavior, behavior_metrics in metrics.items():
                    all_metrics.append({
                        'Time Group': time_group,
                        'Behavior': behavior,
                        **behavior_metrics
                    })

        # DataFrame + save results
        analysis_df = pd.DataFrame(all_metrics)
        analysis_file_path = os.path.join(analysis_dir, f'analysis_{file_name}')
        analysis_df.to_csv(analysis_file_path, index=False)
        print(f'Saved analysis for {file_name} to {analysis_file_path}')

print('Behavior analysis completed for all files.')
# Out:
# Processing file: Male_Group1_0mgkg_3_2088.1M_L3_acA2040-120um__23701299__20230726_120404770DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2088.1M_L3_acA2040-120um__23701299__20230726_120404770DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2088.1M_L3_acA2040-120um__23701299__20230726_120404770DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2088.4M_L2_acA2040-120um__23701274__20230726_124045566DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2088.4M_L2_acA2040-120um__23701274__20230726_124045566DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2088.4M_L2_acA2040-120um__23701274__20230726_124045566DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2093.4F_L3_acA2040-120um__23701299__20230727_124546676DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2093.4F_L3_acA2040-120um__23701299__20230727_124546676DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2093.4F_L3_acA2040-120um__23701299__20230727_124546676DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2101.0F_L3_acA2040-120um__23701299__20230728_120753007DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2101.0F_L3_acA2040-120um__23701299__20230728_120753007DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2101.0F_L3_acA2040-120um__23701299__20230728_120753007DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2088.2M_L4_acA2040-120um__23670846__20230726_120540381DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2088.2M_L4_acA2040-120um__23670846__20230726_120540381DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2088.2M_L4_acA2040-120um__23670846__20230726_120540381DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2097.4F_L3_acA2040-120um__23701299__20230727_155048324DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2097.4F_L3_acA2040-120um__23701299__20230727_155048324DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2097.4F_L3_acA2040-120um__23701299__20230727_155048324DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2101.2_F_L1_acA2040-120um__23670847__20230728_123910637DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2101.2_F_L1_acA2040-120um__23670847__20230728_123910637DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2101.2_F_L1_acA2040-120um__23670847__20230728_123910637DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2093.1F_L4_acA2040-120um__23670846__20230727_120925685DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2093.1F_L4_acA2040-120um__23670846__20230727_120925685DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2093.1F_L4_acA2040-120um__23670846__20230727_120925685DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2095.4_M_L1_acA2040-120um__23670847__20230727_143233933DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2095.4_M_L1_acA2040-120um__23670847__20230727_143233933DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2095.4_M_L1_acA2040-120um__23670847__20230727_143233933DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2092.2M_L4_acA2040-120um__23670846__20230727_113406584DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2092.2M_L4_acA2040-120um__23670846__20230727_113406584DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2092.2M_L4_acA2040-120um__23670846__20230727_113406584DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2097.0F_L3_acA2040-120um__23701299__20230727_151257408DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2097.0F_L3_acA2040-120um__23701299__20230727_151257408DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2097.0F_L3_acA2040-120um__23701299__20230727_151257408DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2090.2F_L2_acA2040-120um__23701274__20230726_135540080DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2090.2F_L2_acA2040-120um__23701274__20230726_135540080DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2090.2F_L2_acA2040-120um__23701274__20230726_135540080DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2091.2M_L3_acA2040-120um__23701299__20230727_105630515DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2091.2M_L3_acA2040-120um__23701299__20230727_105630515DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2091.2M_L3_acA2040-120um__23701299__20230727_105630515DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2103.1_M_L2_acA2040-120um__23701274__20230728_135510478DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2103.1_M_L2_acA2040-120um__23701274__20230728_135510478DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2103.1_M_L2_acA2040-120um__23701274__20230728_135510478DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2089.3F_L2_acA2040-120um__23701274__20230726_131827101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2089.3F_L2_acA2040-120um__23701274__20230726_131827101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2089.3F_L2_acA2040-120um__23701274__20230726_131827101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2096.3_M_L1_acA2040-120um__23670847__20230727_150831120DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2096.3_M_L1_acA2040-120um__23670847__20230727_150831120DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2096.3_M_L1_acA2040-120um__23670847__20230727_150831120DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2104.2M_L4_acA2040-120um__23670846__20230728_143404620DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2104.2M_L4_acA2040-120um__23670846__20230728_143404620DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2104.2M_L4_acA2040-120um__23670846__20230728_143404620DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2089.2F_L1_acA2040-120um__23670847__20230726_131521683DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2089.2F_L1_acA2040-120um__23670847__20230726_131521683DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2089.2F_L1_acA2040-120um__23670847__20230726_131521683DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2105.3_F_L2_acA2040-120um__23701274__20230728_154532945DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2105.3_F_L2_acA2040-120um__23701274__20230728_154532945DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2105.3_F_L2_acA2040-120um__23701274__20230728_154532945DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2103.3M_L4_acA2040-120um__23670846__20230728_135800622DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2103.3M_L4_acA2040-120um__23670846__20230728_135800622DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2103.3M_L4_acA2040-120um__23670846__20230728_135800622DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2094.2_F_L2_acA2040-120um__23701274__20230727_132250261DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2094.2_F_L2_acA2040-120um__23701274__20230727_132250261DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2094.2_F_L2_acA2040-120um__23701274__20230727_132250261DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2098.2_F_L2_acA2040-120um__23701274__20230727_162631080DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2098.2_F_L2_acA2040-120um__23701274__20230727_162631080DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2098.2_F_L2_acA2040-120um__23701274__20230727_162631080DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2089.1F_L4_acA2040-120um__23670846__20230726_124402448DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2089.1F_L4_acA2040-120um__23670846__20230726_124402448DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2089.1F_L4_acA2040-120um__23670846__20230726_124402448DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2089.3F_L3_acA2040-120um__23701299__20230726_132020252DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2089.3F_L3_acA2040-120um__23701299__20230726_132020252DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2089.3F_L3_acA2040-120um__23701299__20230726_132020252DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2099.1_M_L2__acA2040-120um__23701274__20230728_105508045DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2099.1_M_L2__acA2040-120um__23701274__20230728_105508045DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2099.1_M_L2__acA2040-120um__23701274__20230728_105508045DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2099.3M_L4_acA2040-120um__23670846__20230728_105712250DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2099.3M_L4_acA2040-120um__23670846__20230728_105712250DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2099.3M_L4_acA2040-120um__23670846__20230728_105712250DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2096.2M_L4_acA2040-120um__23670846__20230727_143857589DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2096.2M_L4_acA2040-120um__23670846__20230727_143857589DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2096.2M_L4_acA2040-120um__23670846__20230727_143857589DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2098.1_F_L1_acA2040-120um__23670847__20230727_162300682DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2098.1_F_L1_acA2040-120um__23670847__20230727_162300682DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2098.1_F_L1_acA2040-120um__23670847__20230727_162300682DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2090.3F_L3_acA2040-120um__23701299__20230726_135721147DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2090.3F_L3_acA2040-120um__23701299__20230726_135721147DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2090.3F_L3_acA2040-120um__23701299__20230726_135721147DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2102.0F_L4_acA2040-120um__23670846__20230728_124434198DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2102.0F_L4_acA2040-120um__23670846__20230728_124434198DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2102.0F_L4_acA2040-120um__23670846__20230728_124434198DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2106.0F_L4_acA2040-120um__23670846__20230728_154724292DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2106.0F_L4_acA2040-120um__23670846__20230728_154724292DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2106.0F_L4_acA2040-120um__23670846__20230728_154724292DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2101.4F_L3_acA2040-120um__23701299__20230728_124329606DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2101.4F_L3_acA2040-120um__23701299__20230728_124329606DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2101.4F_L3_acA2040-120um__23701299__20230728_124329606DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2095.1_M_L2_acA2040-120um__23701274__20230727_140003330DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2095.1_M_L2_acA2040-120um__23701274__20230727_140003330DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2095.1_M_L2_acA2040-120um__23701274__20230727_140003330DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2100.4_M_L2_acA2040-120um__23701274__20230728_120634439DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2100.4_M_L2_acA2040-120um__23701274__20230728_120634439DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2100.4_M_L2_acA2040-120um__23701274__20230728_120634439DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2098.3F_L3_acA2040-120um__23701299__20230727_162713513DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2098.3F_L3_acA2040-120um__23701299__20230727_162713513DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2098.3F_L3_acA2040-120um__23701299__20230727_162713513DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2092.0_M_L2_acA2040-120um__23701274__20230727_113152401DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2092.0_M_L2_acA2040-120um__23701274__20230727_113152401DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2092.0_M_L2_acA2040-120um__23701274__20230727_113152401DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2091.3M_L4_acA2040-120um__23670846__20230727_105806877DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2091.3M_L4_acA2040-120um__23670846__20230727_105806877DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2091.3M_L4_acA2040-120um__23670846__20230727_105806877DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2104.1M_L3_acA2040-120um__23701299__20230728_143232918DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2104.1M_L3_acA2040-120um__23701299__20230728_143232918DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2104.1M_L3_acA2040-120um__23701299__20230728_143232918DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2102.4F_L4_acA2040-120um__23670846__20230728_132125299DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2102.4F_L4_acA2040-120um__23670846__20230728_132125299DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2102.4F_L4_acA2040-120um__23670846__20230728_132125299DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2087.0M_L1_acA2040-120um__23670847__20230726_112217211DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2087.0M_L1_acA2040-120um__23670847__20230726_112217211DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2087.0M_L1_acA2040-120um__23670847__20230726_112217211DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2100.0_M_L2_acA2040-120um__23701274__20230728_113029503DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2100.0_M_L2_acA2040-120um__23701274__20230728_113029503DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2100.0_M_L2_acA2040-120um__23701274__20230728_113029503DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2088.3M_L1_acA2040-120um__23670847__20230726_123615495DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2088.3M_L1_acA2040-120um__23670847__20230726_123615495DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2088.3M_L1_acA2040-120um__23670847__20230726_123615495DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2087.3M_L4_acA2040-120um__23670846__20230726_112846023DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2087.3M_L4_acA2040-120um__23670846__20230726_112846023DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2087.3M_L4_acA2040-120um__23670846__20230726_112846023DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2093.0F_L3_acA2040-120um__23701299__20230727_120813953DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2093.0F_L3_acA2040-120um__23701299__20230727_120813953DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2093.0F_L3_acA2040-120um__23701299__20230727_120813953DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2101.3_F_L2_acA2040-120um__23701274__20230728_124240475DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2101.3_F_L2_acA2040-120um__23701274__20230728_124240475DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2101.3_F_L2_acA2040-120um__23701274__20230728_124240475DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2098.4_L4_acA2040-120um__23670846__20230727_162833146DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2098.4_L4_acA2040-120um__23670846__20230727_162833146DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2098.4_L4_acA2040-120um__23670846__20230727_162833146DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2100.3_M_L1_acA2040-120um__23670847__20230728_120257418DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2100.3_M_L1_acA2040-120um__23670847__20230728_120257418DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2100.3_M_L1_acA2040-120um__23670847__20230728_120257418DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2095.0_M_L1_acA2040-120um__23670847__20230727_135523906DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2095.0_M_L1_acA2040-120um__23670847__20230727_135523906DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2095.0_M_L1_acA2040-120um__23670847__20230727_135523906DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2089.0F_L3_acA2040-120um__23701299__20230726_124215243DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2089.0F_L3_acA2040-120um__23701299__20230726_124215243DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2089.0F_L3_acA2040-120um__23701299__20230726_124215243DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2105.2_F_L1_acA2040-120um__23670847__20230728_154210957DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2105.2_F_L1_acA2040-120um__23670847__20230728_154210957DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2105.2_F_L1_acA2040-120um__23670847__20230728_154210957DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2104.3_M_L1_acA2040-120um__23670847__20230728_150433732DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2104.3_M_L1_acA2040-120um__23670847__20230728_150433732DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2104.3_M_L1_acA2040-120um__23670847__20230728_150433732DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2102.1_F_L1_acA2040-120um__23670847__20230728_131510960DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2102.1_F_L1_acA2040-120um__23670847__20230728_131510960DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2102.1_F_L1_acA2040-120um__23670847__20230728_131510960DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2106.3_L3_acA2040-120um__23701299__20230728_163805321DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2106.3_L3_acA2040-120um__23701299__20230728_163805321DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2106.3_L3_acA2040-120um__23701299__20230728_163805321DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2097.3_F_L2_acA2040-120um__23701274__20230727_154937725DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2097.3_F_L2_acA2040-120um__23701274__20230727_154937725DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2097.3_F_L2_acA2040-120um__23701274__20230727_154937725DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2104.0_M_L2_acA2040-120um__23701274__20230728_143148849DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2104.0_M_L2_acA2040-120um__23701274__20230728_143148849DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2104.0_M_L2_acA2040-120um__23701274__20230728_143148849DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2090.1F_L1_acA2040-120um__23670847__20230726_135222763DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2090.1F_L1_acA2040-120um__23670847__20230726_135222763DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2090.1F_L1_acA2040-120um__23670847__20230726_135222763DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2087.1M_L2_acA2040-120um__23701274__20230726_112603034DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2087.1M_L2_acA2040-120um__23701274__20230726_112603034DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2087.1M_L2_acA2040-120um__23701274__20230726_112603034DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2100.1M_L3_acA2040-120um__23701299__20230728_113115084DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2100.1M_L3_acA2040-120um__23701299__20230728_113115084DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2100.1M_L3_acA2040-120um__23701299__20230728_113115084DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2094.3F_L3_acA2040-120um__23701299__20230727_132355459DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2094.3F_L3_acA2040-120um__23701299__20230727_132355459DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2094.3F_L3_acA2040-120um__23701299__20230727_132355459DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2105.0F_L3_acA2040-120um__23701299__20230728_150925744DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2105.0F_L3_acA2040-120um__23701299__20230728_150925744DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2105.0F_L3_acA2040-120um__23701299__20230728_150925744DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2092.3_M_L1_acA2040-120um__23670847__20230727_120344244DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2092.3_M_L1_acA2040-120um__23670847__20230727_120344244DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2092.3_M_L1_acA2040-120um__23670847__20230727_120344244DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2103.2M_L3_acA2040-120um__23701299__20230728_135647495DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2103.2M_L3_acA2040-120um__23701299__20230728_135647495DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2103.2M_L3_acA2040-120um__23701299__20230728_135647495DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2094.4F_L4_acA2040-120um__23670846__20230727_132532821DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2094.4F_L4_acA2040-120um__23670846__20230727_132532821DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2094.4F_L4_acA2040-120um__23670846__20230727_132532821DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2099.0_M_L1_acA2040-120um__23670847__20230728_105138774DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2099.0_M_L1_acA2040-120um__23670847__20230728_105138774DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2099.0_M_L1_acA2040-120um__23670847__20230728_105138774DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2104.4_M_L2_acA2040-120um__23701274__20230728_150819132DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2104.4_M_L2_acA2040-120um__23701274__20230728_150819132DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2104.4_M_L2_acA2040-120um__23701274__20230728_150819132DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2091.1_M_L2_acA2040-120um__23701274__20230727_105505493DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2091.1_M_L2_acA2040-120um__23701274__20230727_105505493DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2091.1_M_L2_acA2040-120um__23701274__20230727_105505493DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2101.1F_L4_acA2040-120um__23670846__20230728_120924235DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2101.1F_L4_acA2040-120um__23670846__20230728_120924235DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2101.1F_L4_acA2040-120um__23670846__20230728_120924235DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2092.1M_L3_acA2040-120um__23701299__20230727_113245593DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2092.1M_L3_acA2040-120um__23701299__20230727_113245593DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2092.1M_L3_acA2040-120um__23701299__20230727_113245593DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2096.1M_L3_acA2040-120um__23701299__20230727_143717272DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2096.1M_L3_acA2040-120um__23701299__20230727_143717272DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2096.1M_L3_acA2040-120um__23701299__20230727_143717272DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2095.2M_L3_acA2040-120um__23701299__20230727_140051891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2095.2M_L3_acA2040-120um__23701299__20230727_140051891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2095.2M_L3_acA2040-120um__23701299__20230727_140051891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2096.0_M_L2_acA2040-120um__23701274__20230727_143600535DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2096.0_M_L2_acA2040-120um__23701274__20230727_143600535DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2096.0_M_L2_acA2040-120um__23701274__20230727_143600535DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2088.0M_L2_acA2040-120um__23701274__20230726_120231240DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2088.0M_L2_acA2040-120um__23701274__20230726_120231240DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2088.0M_L2_acA2040-120um__23701274__20230726_120231240DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2106.1_F_L1__acA2040-120um__23670847__20230728_163336257DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2106.1_F_L1__acA2040-120um__23670847__20230728_163336257DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2106.1_F_L1__acA2040-120um__23670847__20230728_163336257DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2097.2_F_L1_acA2040-120um__23670847__20230727_154557912DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2097.2_F_L1_acA2040-120um__23670847__20230727_154557912DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2097.2_F_L1_acA2040-120um__23670847__20230727_154557912DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2102.3F_L3_acA2040-120um__23701299__20230728_132007903DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2102.3F_L3_acA2040-120um__23701299__20230728_132007903DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2102.3F_L3_acA2040-120um__23701299__20230728_132007903DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2087.2M_L3_acA2040-120um__23701299__20230726_112705178DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2087.2M_L3_acA2040-120um__23701299__20230726_112705178DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2087.2M_L3_acA2040-120um__23701299__20230726_112705178DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2098.0F_L4_acA2040-120um__23670846__20230727_155216835DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2098.0F_L4_acA2040-120um__23670846__20230727_155216835DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2098.0F_L4_acA2040-120um__23670846__20230727_155216835DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2106.2_F_L2_acA2040-120um__23701274__20230728_163724581DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2106.2_F_L2_acA2040-120um__23701274__20230728_163724581DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2106.2_F_L2_acA2040-120um__23701274__20230728_163724581DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2094.1_F_L1_acA2040-120um__23670847__20230727_131848577DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2094.1_F_L1_acA2040-120um__23670847__20230727_131848577DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2094.1_F_L1_acA2040-120um__23670847__20230727_131848577DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group1_0mgkg_3_2090.4F_L4_acA2040-120um__23670846__20230726_135906051DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group1_0mgkg_3_2090.4F_L4_acA2040-120um__23670846__20230726_135906051DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group1_0mgkg_3_2090.4F_L4_acA2040-120um__23670846__20230726_135906051DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2099.2M_L3_acA2040-120um__23701299__20230728_105550284DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2099.2M_L3_acA2040-120um__23701299__20230728_105550284DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2099.2M_L3_acA2040-120um__23701299__20230728_105550284DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group1_0mgkg_3_2087.4M_L1_acA2040-120um__23670847__20230726_115819206DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group1_0mgkg_3_2087.4M_L1_acA2040-120um__23670847__20230726_115819206DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group1_0mgkg_3_2087.4M_L1_acA2040-120um__23670847__20230726_115819206DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2105.1F_L4_acA2040-120um__23670846__20230728_151037578DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2105.1F_L4_acA2040-120um__23670846__20230728_151037578DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2105.1F_L4_acA2040-120um__23670846__20230728_151037578DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2093.2_F_L1_acA2040-120um__23670847__20230727_124057710DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2093.2_F_L1_acA2040-120um__23670847__20230727_124057710DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2093.2_F_L1_acA2040-120um__23670847__20230727_124057710DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2094.0F_L4_acA2040-120um__23670846__20230727_124726076DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2094.0F_L4_acA2040-120um__23670846__20230727_124726076DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2094.0F_L4_acA2040-120um__23670846__20230727_124726076DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2099.4_M_L1__acA2040-120um__23670847__20230728_112653313DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2099.4_M_L1__acA2040-120um__23670847__20230728_112653313DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2099.4_M_L1__acA2040-120um__23670847__20230728_112653313DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2095.3M_L4_acA2040-120um__23670846__20230727_140218479DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2095.3M_L4_acA2040-120um__23670846__20230727_140218479DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2095.3M_L4_acA2040-120um__23670846__20230727_140218479DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group3_1.0mgkg_3_2097.1F_L4_acA2040-120um__23670846__20230727_151417984DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group3_1.0mgkg_3_2097.1F_L4_acA2040-120um__23670846__20230727_151417984DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group3_1.0mgkg_3_2097.1F_L4_acA2040-120um__23670846__20230727_151417984DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2105.4F_L3_acA2040-120um__23701299__20230728_154608871DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2105.4F_L3_acA2040-120um__23701299__20230728_154608871DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2105.4F_L3_acA2040-120um__23701299__20230728_154608871DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2091.0_M_L1_acA2040-120um__23670847__20230727_105117744DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2091.0_M_L1_acA2040-120um__23670847__20230727_105117744DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2091.0_M_L1_acA2040-120um__23670847__20230727_105117744DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2103.4_M_L1_acA2040-120um__23670847__20230728_142824849DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2103.4_M_L1_acA2040-120um__23670847__20230728_142824849DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2103.4_M_L1_acA2040-120um__23670847__20230728_142824849DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group2_0.5mgkg_3_2091.4_M_L1_acA2040-120um__23670847__20230727_112807739DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group2_0.5mgkg_3_2091.4_M_L1_acA2040-120um__23670847__20230727_112807739DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group2_0.5mgkg_3_2091.4_M_L1_acA2040-120um__23670847__20230727_112807739DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group4_5mgkg_3_2102.2_F_L2_acA2040-120um__23701274__20230728_131927783DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group4_5mgkg_3_2102.2_F_L2_acA2040-120um__23701274__20230728_131927783DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group4_5mgkg_3_2102.2_F_L2_acA2040-120um__23701274__20230728_131927783DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group2_0.5mgkg_3_2093.3_F_L2_acA2040-120um__23701274__20230727_124438565DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group2_0.5mgkg_3_2093.3_F_L2_acA2040-120um__23701274__20230727_124438565DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group2_0.5mgkg_3_2093.3_F_L2_acA2040-120um__23701274__20230727_124438565DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group5_10mgkg_3_2103.0_M_L1_acA2040-120um__23670847__20230728_135150209DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group5_10mgkg_3_2103.0_M_L1_acA2040-120um__23670847__20230728_135150209DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group5_10mgkg_3_2103.0_M_L1_acA2040-120um__23670847__20230728_135150209DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Female_Group5_10mgkg_3_2106.4_L4_acA2040-120um__23670846__20230728_163906117DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Female_Group5_10mgkg_3_2106.4_L4_acA2040-120um__23670846__20230728_163906117DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Female_Group5_10mgkg_3_2106.4_L4_acA2040-120um__23670846__20230728_163906117DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group3_1.0mgkg_3_2096.4_M_L2_acA2040-120um__23701274__20230727_151209774DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group3_1.0mgkg_3_2096.4_M_L2_acA2040-120um__23701274__20230727_151209774DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group3_1.0mgkg_3_2096.4_M_L2_acA2040-120um__23701274__20230727_151209774DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Male_Group4_5mgkg_3_2100.2M_L4_acA2040-120um__23670846__20230728_113233419DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1800]
# Time Labels: ['0-10 min', '11-30 min']
# Saved analysis for Male_Group4_5mgkg_3_2100.2M_L4_acA2040-120um__23670846__20230728_113233419DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/analysis_Male_Group4_5mgkg_3_2100.2M_L4_acA2040-120um__23670846__20230728_113233419DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Behavior analysis completed for all files.

# %% [markdown]
# ### Cohort Comparisons

# %%
import os
import pandas as pd

# Input and output directories
input_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison'
cohort_summary_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison/cohort_summaries'
os.makedirs(cohort_summary_dir, exist_ok=True)

def aggregate_cohort_data(group_name, condition_list):
    all_metrics = []
    
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv'):
            if any(condition in file_name for condition in condition_list):
                file_path = os.path.join(input_dir, file_name)
                file_data = pd.read_csv(file_path)
                all_metrics.append(file_data)
    
    if not all_metrics:
        print(f"No matching files found for group '{group_name}' with conditions {condition_list}")
        return None
    
    combined_data = pd.concat(all_metrics, ignore_index=True)
    
    summary = combined_data.groupby(['Time Group', 'Behavior']).agg({
        'Fraction Time': ['mean', 'std'],  # Mean and standard deviation
        'Bouts per Minute': ['mean', 'std'],
        'Mean Bout Duration (s)': ['mean', 'std']
    }).reset_index()
    
    summary.columns = ['Time Group', 'Behavior', 
                       'Fraction Time (mean)', 'Fraction Time (std)',
                       'Bouts per Minute (mean)', 'Bouts per Minute (std)',
                       'Mean Bout Duration (mean)', 'Mean Bout Duration (std)']
    
    summary = summary.dropna(subset=[
        'Fraction Time (mean)', 
        'Bouts per Minute (mean)', 
        'Mean Bout Duration (mean)'
    ], how='all')
    
    return summary


for group_name in selected_groups:

    summary = aggregate_cohort_data(group_name, selected_conditions)
    if summary is not None:

        summary_file_path = os.path.join(cohort_summary_dir, f'{group_name}_cohort_summary.csv')
        summary.to_csv(summary_file_path, index=False)
        print(f"Saved cohort summary for group '{group_name}' to {summary_file_path}")

print("Cohort summaries created.")
# Out:
# Saved cohort summary for group 'Male' to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/cohort_summaries/Male_cohort_summary.csv
# Saved cohort summary for group 'Female' to ../processed_dataset/project_ACC_Study3_FormalinMorphine/figures/behavior_timepoint_comparison/cohort_summaries/Female_cohort_summary.csv
# Cohort summaries created.

# %% [markdown]
# # COMPLETE
