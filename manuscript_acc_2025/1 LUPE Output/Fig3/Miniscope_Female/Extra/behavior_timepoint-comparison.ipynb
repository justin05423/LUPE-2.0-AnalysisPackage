# %% [markdown]
# # Behavior Analysis: Comparison of Timepoints

# %% [markdown]
# Press SHIFT + ENTER to run code

# %% [markdown]
# ### USER INPUT!

# %%
## Define project
project_name = 'project_ACC_MiniscopeSNI_Female'

# Select group and condition, see meta.py to see how you previously defined it for your project
selected_groups = ['Baseline','SNI_1Hr','SNI_1Week','SNI_2Week','SNI_3Week','SNI_3WeekMorphine']
selected_conditions = ['NoInjury','SNI']

# %% [markdown]
# ### Main Code: Create Individual CSVs for Timepoint Comparisons (Fraction Time in Behavior; Bouts/Min; Mean Bout Duration)

# %%
### Continue to Press SHIFT + ENTER to run code ###

# Prompt user for input
num_timepoints = int(input("Enter the number of time ranges you want to compare (e.g., 2, 3, etc.): "))
time_ranges = [] # Enter the time ranges IN MINUTES (e.g., 0-10 for 0 to 10 minutes, then 11-30 for remaining 11-30 minutes)

for i in range(num_timepoints):
    time_range = input(f"Time range {i + 1}: ")
    try:
        start_min, end_min = map(int, time_range.split('-'))
        if start_min >= end_min:
            print(f"Error: Start time ({start_min}) must be less than end time ({end_min}).")
            exit()
        start_sec, end_sec = start_min * 60, end_min * 60
        time_ranges.append((start_sec, end_sec))
    except ValueError:
        print("Invalid input format. Please enter the time range as 'start-end' (e.g., 0-10).")
        exit()

# %% [markdown]
# ### Individual File Comparisons

# %%
import os
import pandas as pd

# Validate the time ranges
if len(time_ranges) < 2:
    print("Error: At least two time ranges are required for comparison.")
    exit()

bins = [start for start, end in time_ranges] + [time_ranges[-1][1]]
time_labels = [f"{start//60}-{end//60} min" for start, end in time_ranges]

# Directory containing the per-second CSV files
input_dir = f'../processed_dataset/{project_name}/figures/behaviors_csv_raw-classification/seconds'

# Directory to save the analysis results
analysis_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison'
os.makedirs(analysis_dir, exist_ok=True)

def calculate_behavior_metrics(data, frame_rate=60):
    metrics = {}
    unique_behaviors = data['behavior'].unique()

    for behavior in unique_behaviors:
        behavior_data = data[data['behavior'] == behavior]
        
        fraction_time = len(behavior_data) / len(data)

        bout_starts = (behavior_data.index.to_series().diff() > 1).cumsum()
        bouts = behavior_data.groupby(bout_starts)

        bouts_per_minute = len(bouts) / (len(data) / frame_rate / 60)

        mean_bout_duration = bouts.size().mean() / frame_rate

        metrics[behavior] = {
            'Fraction Time': fraction_time,
            'Bouts per Minute': bouts_per_minute,
            'Mean Bout Duration (s)': mean_bout_duration
        }
    return metrics

# Processing each file
for file_name in os.listdir(input_dir):
    if file_name.endswith('.csv'):
        
        file_path = os.path.join(input_dir, file_name)
        df = pd.read_csv(file_path)
        
        max_time = df['time_seconds'].max()
        
        bins = [start for start, end in time_ranges] + [time_ranges[-1][1]]
        if max_time < bins[-1]:
            print(f"Warning: Maximum time ({max_time}s) in {file_name} is less than the final bin end ({bins[-1]}s).")
            bins[-1] = max_time

        print(f"Processing file: {file_name}")
        print(f"Bins: {bins}")
        print(f"Time Labels: {time_labels}")
        
        try:
            df['time_group'] = pd.cut(df['time_seconds'], 
                                      bins=bins,
                                      labels=time_labels,
                                      right=False)
        except ValueError as e:
            print(f"Error in pd.cut for file {file_name}: {e}")
            continue 
        
        # Analyzing behaviors for each time group
        all_metrics = []
        for time_group, group_data in df.groupby('time_group', observed=False):
            if not group_data.empty:
                metrics = calculate_behavior_metrics(group_data)
                for behavior, behavior_metrics in metrics.items():
                    all_metrics.append({
                        'Time Group': time_group,
                        'Behavior': behavior,
                        **behavior_metrics
                    })

        # DataFrame + save results
        analysis_df = pd.DataFrame(all_metrics)
        analysis_file_path = os.path.join(analysis_dir, f'analysis_{file_name}')
        analysis_df.to_csv(analysis_file_path, index=False)
        print(f'Saved analysis for {file_name} to {analysis_file_path}')

print('Behavior analysis completed for all files.')
# Out:
# Processing file: SNI_3WeekMorphine_SNI_CSO15_Morphine_Basler_acA2040-120um__23670847__20241218_135241113DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_SNI_CSO15_Morphine_Basler_acA2040-120um__23670847__20241218_135241113DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_SNI_CSO15_Morphine_Basler_acA2040-120um__23670847__20241218_135241113DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3Week_SNI_MM98_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_SNI_MM98_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_SNI_MM98_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_SNI_CSO24_2weeks_Basler_acA2040-120um__23670846__20250122_115809809DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_SNI_CSO24_2weeks_Basler_acA2040-120um__23670846__20250122_115809809DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_SNI_CSO24_2weeks_Basler_acA2040-120um__23670846__20250122_115809809DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_SNI_CSO25_Baseline_Basler_acA2040-120um__23670846__20250107_132615288DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_SNI_CSO25_Baseline_Basler_acA2040-120um__23670846__20250107_132615288DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_SNI_CSO25_Baseline_Basler_acA2040-120um__23670846__20250107_132615288DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3Week_NoInjury_MM105_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_NoInjury_MM105_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_NoInjury_MM105_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_SNI_CSO23_1week_Basler_acA2040-120um__23701274__20250115_121649327DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_SNI_CSO23_1week_Basler_acA2040-120um__23701274__20250115_121649327DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_SNI_CSO23_1week_Basler_acA2040-120um__23701274__20250115_121649327DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3Week_NoInjury_MM103_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_NoInjury_MM103_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_NoInjury_MM103_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_NoInjury_CSO22_2weeks_Basler_acA2040-120um__23670846__20250122_134825730DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_NoInjury_CSO22_2weeks_Basler_acA2040-120um__23670846__20250122_134825730DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_NoInjury_CSO22_2weeks_Basler_acA2040-120um__23670846__20250122_134825730DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_NoInjury_MM112_Baseline_Basler_acA2040-120um__23670846__20250107_112755246DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_NoInjury_MM112_Baseline_Basler_acA2040-120um__23670846__20250107_112755246DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_NoInjury_MM112_Baseline_Basler_acA2040-120um__23670846__20250107_112755246DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_SNI_MM108_1week_Basler_acA2040-120um__23701274__20250115_125257332DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_SNI_MM108_1week_Basler_acA2040-120um__23701274__20250115_125257332DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_SNI_MM108_1week_Basler_acA2040-120um__23701274__20250115_125257332DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Warning: Maximum time (1385.4166666666667s) in SNI_3Week_NoInjury_MM104_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv is less than the final bin end (1800s).
# Processing file: SNI_3Week_NoInjury_MM104_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1385.4166666666667]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_NoInjury_MM104_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_NoInjury_MM104_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3Week_NoInjury_CSO18_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_NoInjury_CSO18_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_NoInjury_CSO18_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_SNI_CSO25_1hr_Basler_acA2040-120um__23670846__20250108_140527763DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_SNI_CSO25_1hr_Basler_acA2040-120um__23670846__20250108_140527763DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_SNI_CSO25_1hr_Basler_acA2040-120um__23670846__20250108_140527763DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_NoInjury_MM109_2weeks_Basler_acA2040-120um__23701274__20250122_110641291DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_NoInjury_MM109_2weeks_Basler_acA2040-120um__23701274__20250122_110641291DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_NoInjury_MM109_2weeks_Basler_acA2040-120um__23701274__20250122_110641291DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_NoInjury_CSO20_2weeks_Basler_acA2040-120um__23701274__20250122_114325204DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_NoInjury_CSO20_2weeks_Basler_acA2040-120um__23701274__20250122_114325204DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_NoInjury_CSO20_2weeks_Basler_acA2040-120um__23701274__20250122_114325204DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_SNI_CSO25_2weeks_Basler_acA2040-120um__23670846__20250122_131223750DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_SNI_CSO25_2weeks_Basler_acA2040-120um__23670846__20250122_131223750DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_SNI_CSO25_2weeks_Basler_acA2040-120um__23670846__20250122_131223750DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_SNI_MM110_2weeks_Basler_acA2040-120um__23701274__20250122_133432359DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_SNI_MM110_2weeks_Basler_acA2040-120um__23701274__20250122_133432359DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_SNI_MM110_2weeks_Basler_acA2040-120um__23701274__20250122_133432359DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3WeekMorphine_NoInjury_MM103_Morphine_Basler_acA2040-120um__23670847__20241218_101558370DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_NoInjury_MM103_Morphine_Basler_acA2040-120um__23670847__20241218_101558370DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_NoInjury_MM103_Morphine_Basler_acA2040-120um__23670847__20241218_101558370DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_NoInjury_CSO22_1week_Basler_acA2040-120um__23670846__20250115_134235279DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_NoInjury_CSO22_1week_Basler_acA2040-120um__23670846__20250115_134235279DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_NoInjury_CSO22_1week_Basler_acA2040-120um__23670846__20250115_134235279DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3Week_SNI_CSO17_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_SNI_CSO17_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_SNI_CSO17_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_NoInjury_CSO20_Baseline_Basler_acA2040-120um__23701274__20250107_115355049DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_NoInjury_CSO20_Baseline_Basler_acA2040-120um__23701274__20250107_115355049DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_NoInjury_CSO20_Baseline_Basler_acA2040-120um__23701274__20250107_115355049DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_NoInjury_CSO20_1hr_Basler_acA2040-120um__23701274__20250108_122612509DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_NoInjury_CSO20_1hr_Basler_acA2040-120um__23701274__20250108_122612509DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_NoInjury_CSO20_1hr_Basler_acA2040-120um__23701274__20250108_122612509DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_SNI_CSO23_1hr_Basler_acA2040-120um__23701274__20250108_131117343DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_SNI_CSO23_1hr_Basler_acA2040-120um__23701274__20250108_131117343DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_SNI_CSO23_1hr_Basler_acA2040-120um__23701274__20250108_131117343DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3WeekMorphine_SNI_CSO17_Morphine_Basler_acA2040-120um__23670847__20241218_143157914DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_SNI_CSO17_Morphine_Basler_acA2040-120um__23670847__20241218_143157914DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_SNI_CSO17_Morphine_Basler_acA2040-120um__23670847__20241218_143157914DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3WeekMorphine_NoInjury_MM105_Morphine_Basler_acA2040-120um__23670847__20241218_113306366DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_NoInjury_MM105_Morphine_Basler_acA2040-120um__23670847__20241218_113306366DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_NoInjury_MM105_Morphine_Basler_acA2040-120um__23670847__20241218_113306366DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_SNI_CSO24_1hr_Basler_acA2040-120um__23670846__20250108_123548818DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_SNI_CSO24_1hr_Basler_acA2040-120um__23670846__20250108_123548818DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_SNI_CSO24_1hr_Basler_acA2040-120um__23670846__20250108_123548818DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_SNI_MM108_1hr_Basler_acA2040-120um__23701274__20250108_135533264DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_SNI_MM108_1hr_Basler_acA2040-120um__23701274__20250108_135533264DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_SNI_MM108_1hr_Basler_acA2040-120um__23701274__20250108_135533264DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_SNI_CSO23_Baseline_Basler_acA2040-120um__23701274__20250107_123204151DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_SNI_CSO23_Baseline_Basler_acA2040-120um__23701274__20250107_123204151DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_SNI_CSO23_Baseline_Basler_acA2040-120um__23701274__20250107_123204151DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_NoInjury_CSO20_1week_Basler_acA2040-120um__23701274__20250115_113815587DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_NoInjury_CSO20_1week_Basler_acA2040-120um__23701274__20250115_113815587DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_NoInjury_CSO20_1week_Basler_acA2040-120um__23701274__20250115_113815587DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_SNI_CSO24_1week_Basler_acA2040-120um__23670846__20250115_115144880DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_SNI_CSO24_1week_Basler_acA2040-120um__23670846__20250115_115144880DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_SNI_CSO24_1week_Basler_acA2040-120um__23670846__20250115_115144880DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_SNI_CSO24_Baseline_Basler_acA2040-120um__23670846__20250107_121030902DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_SNI_CSO24_Baseline_Basler_acA2040-120um__23670846__20250107_121030902DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_SNI_CSO24_Baseline_Basler_acA2040-120um__23670846__20250107_121030902DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_NoInjury_MM112_1week_Basler_acA2040-120um__23670846__20250115_111418867DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_NoInjury_MM112_1week_Basler_acA2040-120um__23670846__20250115_111418867DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_NoInjury_MM112_1week_Basler_acA2040-120um__23670846__20250115_111418867DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3WeekMorphine_SNI_CSO19_Morphine_Basler_acA2040-120um__23670847__20241218_150718086DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_SNI_CSO19_Morphine_Basler_acA2040-120um__23670847__20241218_150718086DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_SNI_CSO19_Morphine_Basler_acA2040-120um__23670847__20241218_150718086DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3WeekMorphine_NoInjury_MM104_Morphine_Basler_acA2040-120um__23670847__20241218_105309133DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_NoInjury_MM104_Morphine_Basler_acA2040-120um__23670847__20241218_105309133DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_NoInjury_MM104_Morphine_Basler_acA2040-120um__23670847__20241218_105309133DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_NoInjury_MM109_1week_Basler_acA2040-120um__23701274__20250115_110045569DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_NoInjury_MM109_1week_Basler_acA2040-120um__23701274__20250115_110045569DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_NoInjury_MM109_1week_Basler_acA2040-120um__23701274__20250115_110045569DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3WeekMorphine_NoInjury_CSO18_Morphine_Basler_acA2040-120um__23670847__20241218_120945118DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_NoInjury_CSO18_Morphine_Basler_acA2040-120um__23670847__20241218_120945118DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_NoInjury_CSO18_Morphine_Basler_acA2040-120um__23670847__20241218_120945118DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_SNI_MM110_1hr_Basler_acA2040-120um__23701274__20250108_144044300DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_SNI_MM110_1hr_Basler_acA2040-120um__23701274__20250108_144044300DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_SNI_MM110_1hr_Basler_acA2040-120um__23701274__20250108_144044300DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_NoInjury_MM109_Baseline_Basler_acA2040-120um__23701274__20250107_111527114DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_NoInjury_MM109_Baseline_Basler_acA2040-120um__23701274__20250107_111527114DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_NoInjury_MM109_Baseline_Basler_acA2040-120um__23701274__20250107_111527114DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_NoInjury_CSO21_2weeks_Basler_acA2040-120um__23670846__20250122_123444489DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_NoInjury_CSO21_2weeks_Basler_acA2040-120um__23670846__20250122_123444489DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_NoInjury_CSO21_2weeks_Basler_acA2040-120um__23670846__20250122_123444489DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_NoInjury_MM109_1hr_Basler_acA2040-120um__23701274__20250108_114346480DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_NoInjury_MM109_1hr_Basler_acA2040-120um__23701274__20250108_114346480DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_NoInjury_MM109_1hr_Basler_acA2040-120um__23701274__20250108_114346480DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_SNI_MM110_Baseline_Basler_acA2040-120um__23701274__20250107_135201007DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_SNI_MM110_Baseline_Basler_acA2040-120um__23701274__20250107_135201007DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_SNI_MM110_Baseline_Basler_acA2040-120um__23701274__20250107_135201007DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_NoInjury_MM112_2weeks_Basler_acA2040-120um__23670846__20250122_112003968DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_NoInjury_MM112_2weeks_Basler_acA2040-120um__23670846__20250122_112003968DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_NoInjury_MM112_2weeks_Basler_acA2040-120um__23670846__20250122_112003968DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_NoInjury_CSO21_Baseline_Basler_acA2040-120um__23670846__20250107_124912281DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_NoInjury_CSO21_Baseline_Basler_acA2040-120um__23670846__20250107_124912281DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_NoInjury_CSO21_Baseline_Basler_acA2040-120um__23670846__20250107_124912281DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_SNI_CSO23_2weeks_Basler_acA2040-120um__23701274__20250122_121941197DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_SNI_CSO23_2weeks_Basler_acA2040-120um__23701274__20250122_121941197DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_SNI_CSO23_2weeks_Basler_acA2040-120um__23701274__20250122_121941197DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_NoInjury_CSO21_1hr_Basler_acA2040-120um__23670846__20250108_132138790DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_NoInjury_CSO21_1hr_Basler_acA2040-120um__23670846__20250108_132138790DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_NoInjury_CSO21_1hr_Basler_acA2040-120um__23670846__20250108_132138790DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_NoInjury_CSO21_1week_Basler_acA2040-120um__23670846__20250115_122746652DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_NoInjury_CSO21_1week_Basler_acA2040-120um__23670846__20250115_122746652DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_NoInjury_CSO21_1week_Basler_acA2040-120um__23670846__20250115_122746652DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3Week_SNI_CSO15_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_SNI_CSO15_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_SNI_CSO15_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_NoInjury_MM112_1hr_Basler_acA2040-120um__23670846__20250108_115612060DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_NoInjury_MM112_1hr_Basler_acA2040-120um__23670846__20250108_115612060DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_NoInjury_MM112_1hr_Basler_acA2040-120um__23670846__20250108_115612060DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3Week_SNI_CSO19_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3Week_SNI_CSO19_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3Week_SNI_CSO19_3weeksDLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_NoInjury_CSO22_Baseline_Basler_acA2040-120um__23670846__20250107_140618213DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_NoInjury_CSO22_Baseline_Basler_acA2040-120um__23670846__20250107_140618213DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_NoInjury_CSO22_Baseline_Basler_acA2040-120um__23670846__20250107_140618213DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: Baseline_SNI_MM108_Baseline_Basler_acA2040-120um__23701274__20250107_131532873DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for Baseline_SNI_MM108_Baseline_Basler_acA2040-120um__23701274__20250107_131532873DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_Baseline_SNI_MM108_Baseline_Basler_acA2040-120um__23701274__20250107_131532873DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_3WeekMorphine_SNI_MM98_Morphine_Basler_acA2040-120um__23670847__20241218_131416101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_3WeekMorphine_SNI_MM98_Morphine_Basler_acA2040-120um__23670847__20241218_131416101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_3WeekMorphine_SNI_MM98_Morphine_Basler_acA2040-120um__23670847__20241218_131416101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Hr_NoInjury_CSO22_1hr_Basler_acA2040-120um__23670846__20250108_144736925DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Hr_NoInjury_CSO22_1hr_Basler_acA2040-120um__23670846__20250108_144736925DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Hr_NoInjury_CSO22_1hr_Basler_acA2040-120um__23670846__20250108_144736925DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_SNI_CSO25_1week_Basler_acA2040-120um__23670846__20250115_130520767DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_SNI_CSO25_1week_Basler_acA2040-120um__23670846__20250115_130520767DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_SNI_CSO25_1week_Basler_acA2040-120um__23670846__20250115_130520767DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_2Week_SNI_MM108_2weeks_Basler_acA2040-120um__23701274__20250122_125642943DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_2Week_SNI_MM108_2weeks_Basler_acA2040-120um__23701274__20250122_125642943DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_2Week_SNI_MM108_2weeks_Basler_acA2040-120um__23701274__20250122_125642943DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: SNI_1Week_SNI_MM110_1week_Basler_acA2040-120um__23701274__20250115_133016411DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for SNI_1Week_SNI_MM110_1week_Basler_acA2040-120um__23701274__20250115_133016411DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/analysis_SNI_1Week_SNI_MM110_1week_Basler_acA2040-120um__23701274__20250115_133016411DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Behavior analysis completed for all files.

# %% [markdown]
# ### Cohort Comparisons

# %%
import os
import pandas as pd

# Input and output directories
input_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison'
cohort_summary_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison/cohort_summaries'
os.makedirs(cohort_summary_dir, exist_ok=True)

def aggregate_cohort_data(group_name, condition_list):
    all_metrics = []
    
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv'):
            if any(condition in file_name for condition in condition_list):
                file_path = os.path.join(input_dir, file_name)
                file_data = pd.read_csv(file_path)
                all_metrics.append(file_data)
    
    if not all_metrics:
        print(f"No matching files found for group '{group_name}' with conditions {condition_list}")
        return None
    
    combined_data = pd.concat(all_metrics, ignore_index=True)
    
    summary = combined_data.groupby(['Time Group', 'Behavior']).agg({
        'Fraction Time': ['mean', 'std'],  # Mean and standard deviation
        'Bouts per Minute': ['mean', 'std'],
        'Mean Bout Duration (s)': ['mean', 'std']
    }).reset_index()
    
    summary.columns = ['Time Group', 'Behavior', 
                       'Fraction Time (mean)', 'Fraction Time (std)',
                       'Bouts per Minute (mean)', 'Bouts per Minute (std)',
                       'Mean Bout Duration (mean)', 'Mean Bout Duration (std)']
    
    summary = summary.dropna(subset=[
        'Fraction Time (mean)', 
        'Bouts per Minute (mean)', 
        'Mean Bout Duration (mean)'
    ], how='all')
    
    return summary


for group_name in selected_groups:

    summary = aggregate_cohort_data(group_name, selected_conditions)
    if summary is not None:

        summary_file_path = os.path.join(cohort_summary_dir, f'{group_name}_cohort_summary.csv')
        summary.to_csv(summary_file_path, index=False)
        print(f"Saved cohort summary for group '{group_name}' to {summary_file_path}")

print("Cohort summaries created.")
# Out:
# Saved cohort summary for group 'Baseline' to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/cohort_summaries/Baseline_cohort_summary.csv
# Saved cohort summary for group 'SNI_1Hr' to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/cohort_summaries/SNI_1Hr_cohort_summary.csv
# Saved cohort summary for group 'SNI_1Week' to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/cohort_summaries/SNI_1Week_cohort_summary.csv
# Saved cohort summary for group 'SNI_2Week' to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/cohort_summaries/SNI_2Week_cohort_summary.csv
# Saved cohort summary for group 'SNI_3Week' to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/cohort_summaries/SNI_3Week_cohort_summary.csv
# Saved cohort summary for group 'SNI_3WeekMorphine' to ../processed_dataset/project_ACC_MiniscopeSNI_Female/figures/behavior_timepoint_comparison/cohort_summaries/SNI_3WeekMorphine_cohort_summary.csv
# Cohort summaries created.

# %% [markdown]
# # COMPLETE
