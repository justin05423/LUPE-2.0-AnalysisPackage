# %% [markdown]
# # Behavior Analysis: Comparison of Timepoints

# %% [markdown]
# Press SHIFT + ENTER to run code

# %% [markdown]
# ### USER INPUT!

# %%
## Define project
project_name = 'project_ACC_MORPDreadd_Combined'

# Select group and condition, see meta.py to see how you previously defined it for your project
selected_groups = ['A_Baseline_NoSNI','B_Baseline_SNI','C_3WSNI_DCZ','D_4WSNI_DCZ']
selected_conditions = ['Exp_mMORPhm4di','Control_mMORPeYFP']

# %% [markdown]
# ### Main Code: Create Individual CSVs for Timepoint Comparisons (Fraction Time in Behavior; Bouts/Min; Mean Bout Duration)

# %%
### Continue to Press SHIFT + ENTER to run code ###

# Prompt user for input
num_timepoints = int(input("Enter the number of time ranges you want to compare (e.g., 2, 3, etc.): "))
time_ranges = [] # Enter the time ranges IN MINUTES (e.g., 0-10 for 0 to 10 minutes, then 11-30 for remaining 11-30 minutes)

for i in range(num_timepoints):
    time_range = input(f"Time range {i + 1}: ")
    try:
        start_min, end_min = map(int, time_range.split('-'))
        if start_min >= end_min:
            print(f"Error: Start time ({start_min}) must be less than end time ({end_min}).")
            exit()
        start_sec, end_sec = start_min * 60, end_min * 60
        time_ranges.append((start_sec, end_sec))
    except ValueError:
        print("Invalid input format. Please enter the time range as 'start-end' (e.g., 0-10).")
        exit()

# %% [markdown]
# ### Individual File Comparisons

# %%
import os
import pandas as pd

# Validate the time ranges
if len(time_ranges) < 2:
    print("Error: At least two time ranges are required for comparison.")
    exit()

bins = [start for start, end in time_ranges] + [time_ranges[-1][1]]
time_labels = [f"{start//60}-{end//60} min" for start, end in time_ranges]

# Directory containing the per-second CSV files
input_dir = f'../processed_dataset/{project_name}/figures/behaviors_csv_raw-classification/seconds'

# Directory to save the analysis results
analysis_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison'
os.makedirs(analysis_dir, exist_ok=True)

def calculate_behavior_metrics(data, frame_rate=60):
    metrics = {}
    unique_behaviors = data['behavior'].unique()

    for behavior in unique_behaviors:
        behavior_data = data[data['behavior'] == behavior]
        
        fraction_time = len(behavior_data) / len(data)

        bout_starts = (behavior_data.index.to_series().diff() > 1).cumsum()
        bouts = behavior_data.groupby(bout_starts)

        bouts_per_minute = len(bouts) / (len(data) / frame_rate / 60)

        mean_bout_duration = bouts.size().mean() / frame_rate

        metrics[behavior] = {
            'Fraction Time': fraction_time,
            'Bouts per Minute': bouts_per_minute,
            'Mean Bout Duration (s)': mean_bout_duration
        }
    return metrics

# Processing each file
for file_name in os.listdir(input_dir):
    if file_name.endswith('.csv'):
        
        file_path = os.path.join(input_dir, file_name)
        df = pd.read_csv(file_path)
        
        max_time = df['time_seconds'].max()
        
        bins = [start for start, end in time_ranges] + [time_ranges[-1][1]]
        if max_time < bins[-1]:
            print(f"Warning: Maximum time ({max_time}s) in {file_name} is less than the final bin end ({bins[-1]}s).")
            bins[-1] = max_time

        print(f"Processing file: {file_name}")
        print(f"Bins: {bins}")
        print(f"Time Labels: {time_labels}")
        
        try:
            df['time_group'] = pd.cut(df['time_seconds'], 
                                      bins=bins,
                                      labels=time_labels,
                                      right=False)
        except ValueError as e:
            print(f"Error in pd.cut for file {file_name}: {e}")
            continue 
        
        # Analyzing behaviors for each time group
        all_metrics = []
        for time_group, group_data in df.groupby('time_group', observed=False):
            if not group_data.empty:
                metrics = calculate_behavior_metrics(group_data)
                for behavior, behavior_metrics in metrics.items():
                    all_metrics.append({
                        'Time Group': time_group,
                        'Behavior': behavior,
                        **behavior_metrics
                    })

        # DataFrame + save results
        analysis_df = pd.DataFrame(all_metrics)
        analysis_file_path = os.path.join(analysis_dir, f'analysis_{file_name}')
        analysis_df.to_csv(analysis_file_path, index=False)
        print(f'Saved analysis for {file_name} to {analysis_file_path}')

print('Behavior analysis completed for all files.')
# Out:
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_2.3F3_acA2040-120um__23670846__20230317_134543320DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_2.3F3_acA2040-120um__23670846__20230317_134543320DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_2.3F3_acA2040-120um__23670846__20230317_134543320DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F3_acA2040-120um__23670846__20230425_145303660DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F3_acA2040-120um__23670846__20230425_145303660DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F3_acA2040-120um__23670846__20230425_145303660DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F2_acA2040-120um__23670846__20230414_124407954DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F2_acA2040-120um__23670846__20230414_124407954DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F2_acA2040-120um__23670846__20230414_124407954DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.2M1_acA2040-120um__23670847__20230324_114054557DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.2M1_acA2040-120um__23670847__20230324_114054557DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.2M1_acA2040-120um__23670847__20230324_114054557DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M3_acA2040-120um__23670846__20230331_114832645DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M3_acA2040-120um__23670846__20230331_114832645DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M3_acA2040-120um__23670846__20230331_114832645DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M1_acA2040-120um__23670846__20230331_111506721DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M1_acA2040-120um__23670846__20230331_111506721DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M1_acA2040-120um__23670846__20230331_111506721DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M3_acA2040-120um__23670847__20230330_120928736DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M3_acA2040-120um__23670847__20230330_120928736DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M3_acA2040-120um__23670847__20230330_120928736DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M1_acA2040-120um__23670846__20230330_103013305DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M1_acA2040-120um__23670846__20230330_103013305DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M1_acA2040-120um__23670846__20230330_103013305DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.1M1_acA2040-120um__23670846__20230324_103218840DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.1M1_acA2040-120um__23670846__20230324_103218840DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.1M1_acA2040-120um__23670846__20230324_103218840DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_2.1F5_acA2040-120um__23670846__20230317_114059213DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_2.1F5_acA2040-120um__23670846__20230317_114059213DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_2.1F5_acA2040-120um__23670846__20230317_114059213DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F3_acA2040-120um__23670846__20230424_145646907DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F3_acA2040-120um__23670846__20230424_145646907DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F3_acA2040-120um__23670846__20230424_145646907DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M4_acA2040-120um__23670847__20230331_115108340DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M4_acA2040-120um__23670847__20230331_115108340DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M4_acA2040-120um__23670847__20230331_115108340DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M2_acA2040-120um__23670846__20230418_122820231DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M2_acA2040-120um__23670846__20230418_122820231DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M2_acA2040-120um__23670846__20230418_122820231DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M5_acA2040-120um__23670847__20230303_132309539DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M5_acA2040-120um__23670847__20230303_132309539DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M5_acA2040-120um__23670847__20230303_132309539DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.1M2_acA2040-120um__23670847__20230324_103455637DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.1M2_acA2040-120um__23670847__20230324_103455637DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.1M2_acA2040-120um__23670847__20230324_103455637DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M4_acA2040-120um__23670847__20230418_112923528DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M4_acA2040-120um__23670847__20230418_112923528DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M4_acA2040-120um__23670847__20230418_112923528DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M4_acA2040-120um__23670846__20230303_131834201DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M4_acA2040-120um__23670846__20230303_131834201DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M4_acA2040-120um__23670846__20230303_131834201DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F4_acA2040-120um__23670847__20230414_114343824DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F4_acA2040-120um__23670847__20230414_114343824DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F4_acA2040-120um__23670847__20230414_114343824DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_2.2F5_acA2040-120um__23670847__20230317_124829638DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_2.2F5_acA2040-120um__23670847__20230317_124829638DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_2.2F5_acA2040-120um__23670847__20230317_124829638DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.2M3_acA2040-120um__23670847__20230425_132302683DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.2M3_acA2040-120um__23670847__20230425_132302683DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.2M3_acA2040-120um__23670847__20230425_132302683DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M2_acA2040-120um__23670847__20230330_131248756DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M2_acA2040-120um__23670847__20230330_131248756DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M2_acA2040-120um__23670847__20230330_131248756DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M1_acA2040-120um__23670847__20230330_113744645DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M1_acA2040-120um__23670847__20230330_113744645DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M1_acA2040-120um__23670847__20230330_113744645DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.4F3_acA2040-120um__23670847__20230324_144912699DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.4F3_acA2040-120um__23670847__20230324_144912699DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.4F3_acA2040-120um__23670847__20230324_144912699DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M5_acA2040-120um__23670846__20230330_141136041DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M5_acA2040-120um__23670846__20230330_141136041DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M5_acA2040-120um__23670846__20230330_141136041DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F2_acA2040-120um__23670846__20230413_124531676DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F2_acA2040-120um__23670846__20230413_124531676DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F2_acA2040-120um__23670846__20230413_124531676DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.1M1_acA2040-120um__23670846__20230425_114456663DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.1M1_acA2040-120um__23670846__20230425_114456663DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.1M1_acA2040-120um__23670846__20230425_114456663DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M4_acA2040-120um__23670847__20230407_120709809DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M4_acA2040-120um__23670847__20230407_120709809DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M4_acA2040-120um__23670847__20230407_120709809DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F2_acA2040-120um__23670847__20230417_135102529DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F2_acA2040-120um__23670847__20230417_135102529DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F2_acA2040-120um__23670847__20230417_135102529DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F4_acA2040-120um__23670846__20230414_131645875DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F4_acA2040-120um__23670846__20230414_131645875DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F4_acA2040-120um__23670846__20230414_131645875DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M1_acA2040-120um__23670846__20230407_113133162DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M1_acA2040-120um__23670846__20230407_113133162DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M1_acA2040-120um__23670846__20230407_113133162DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F1_acA2040-120um__23670846__20230425_142136891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F1_acA2040-120um__23670846__20230425_142136891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F1_acA2040-120um__23670846__20230425_142136891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F2_acA2040-120um__23670846__20230425_155621124DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F2_acA2040-120um__23670846__20230425_155621124DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F2_acA2040-120um__23670846__20230425_155621124DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_2.3F2_acA2040-120um__23670847__20230317_132003148DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_2.3F2_acA2040-120um__23670847__20230317_132003148DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_2.3F2_acA2040-120um__23670847__20230317_132003148DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F5_acA2040-120um__23670846__20230417_141828908DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F5_acA2040-120um__23670846__20230417_141828908DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F5_acA2040-120um__23670846__20230417_141828908DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F3_acA2040-120um__23670847__20230417_152553385DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F3_acA2040-120um__23670847__20230417_152553385DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F3_acA2040-120um__23670847__20230417_152553385DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F5_acA2040-120um__23670846__20230425_152504642DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F5_acA2040-120um__23670846__20230425_152504642DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F5_acA2040-120um__23670846__20230425_152504642DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M2_acA2040-120um__23670846__20230417_121030622DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M2_acA2040-120um__23670846__20230417_121030622DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M2_acA2040-120um__23670846__20230417_121030622DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.3F4_acA2040-120um__23670847__20230414_142359924DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.3F4_acA2040-120um__23670847__20230414_142359924DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.3F4_acA2040-120um__23670847__20230414_142359924DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M5_acA2040-120um__23670846__20230330_113254179DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M5_acA2040-120um__23670846__20230330_113254179DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M5_acA2040-120um__23670846__20230330_113254179DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.2M3_acA2040-120um__23670847__20230324_121233447DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.2M3_acA2040-120um__23670847__20230324_121233447DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.2M3_acA2040-120um__23670847__20230324_121233447DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.3M4_acA2040-120um__23670847__20230331_143838481DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.3M4_acA2040-120um__23670847__20230331_143838481DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.3M4_acA2040-120um__23670847__20230331_143838481DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F5_acA2040-120um__23670847__20230413_132159911DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F5_acA2040-120um__23670847__20230413_132159911DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F5_acA2040-120um__23670847__20230413_132159911DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_1.3M3_acA2040-120um__23670846__20230303_143103406DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_1.3M3_acA2040-120um__23670846__20230303_143103406DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_1.3M3_acA2040-120um__23670846__20230303_143103406DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M2_acA2040-120um__23670847__20230418_105713564DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M2_acA2040-120um__23670847__20230418_105713564DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M2_acA2040-120um__23670847__20230418_105713564DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.4F1_acA2040-120um__23670847__20230324_141810912DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.4F1_acA2040-120um__23670847__20230324_141810912DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.4F1_acA2040-120um__23670847__20230324_141810912DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.2M2_acA2040-120um__23670846__20230407_130830171DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.2M2_acA2040-120um__23670846__20230407_130830171DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.2M2_acA2040-120um__23670846__20230407_130830171DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.4F2_acA2040-120um__23670846__20230324_144400464DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.4F2_acA2040-120um__23670846__20230324_144400464DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.4F2_acA2040-120um__23670846__20230324_144400464DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.3F3_acA2040-120um__23670846__20230418_140508598DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.3F3_acA2040-120um__23670846__20230418_140508598DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.3F3_acA2040-120um__23670846__20230418_140508598DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F1_acA2040-120um__23670846__20230413_134823980DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F1_acA2040-120um__23670846__20230413_134823980DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F1_acA2040-120um__23670846__20230413_134823980DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M1_acA2040-120um__23670846__20230330_130801607DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M1_acA2040-120um__23670846__20230330_130801607DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.3M1_acA2040-120um__23670846__20230330_130801607DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F4_acA2040-120um__23670847__20230425_145719307DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F4_acA2040-120um__23670847__20230425_145719307DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.3F4_acA2040-120um__23670847__20230425_145719307DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F5_acA2040-120um__23670846__20230414_121146404DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F5_acA2040-120um__23670846__20230414_121146404DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F5_acA2040-120um__23670846__20230414_121146404DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F5_acA2040-120um__23670846__20230413_145104458DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F5_acA2040-120um__23670846__20230413_145104458DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F5_acA2040-120um__23670846__20230413_145104458DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.3M5_acA2040-120um__23670846__20230331_150906800DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.3M5_acA2040-120um__23670846__20230331_150906800DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.3M5_acA2040-120um__23670846__20230331_150906800DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F4_acA2040-120um__23670846__20230413_131654521DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F4_acA2040-120um__23670846__20230413_131654521DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F4_acA2040-120um__23670846__20230413_131654521DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_2.2F1_acA2040-120um__23670847__20230317_114521312DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_2.2F1_acA2040-120um__23670847__20230317_114521312DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_2.2F1_acA2040-120um__23670847__20230317_114521312DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M5_acA2040-120um__23670846__20230331_122218045DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M5_acA2040-120um__23670846__20230331_122218045DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M5_acA2040-120um__23670846__20230331_122218045DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.2M1_acA2040-120um__23670847__20230407_124020752DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.2M1_acA2040-120um__23670847__20230407_124020752DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.2M1_acA2040-120um__23670847__20230407_124020752DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F2_acA2040-120um__23670846__20230417_144916710DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F2_acA2040-120um__23670846__20230417_144916710DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F2_acA2040-120um__23670846__20230417_144916710DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F3_acA2040-120um__23670846__20230413_141942457DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F3_acA2040-120um__23670846__20230413_141942457DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F3_acA2040-120um__23670846__20230413_141942457DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.4F1_acA2040-120um__23670847__20230418_143929708DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.4F1_acA2040-120um__23670847__20230418_143929708DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.4F1_acA2040-120um__23670847__20230418_143929708DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F3_acA2040-120um__23670846__20230417_134715908DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F3_acA2040-120um__23670846__20230417_134715908DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.3F3_acA2040-120um__23670846__20230417_134715908DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M4_acA2040-120um__23670847__20230407_144755101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M4_acA2040-120um__23670847__20230407_144755101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M4_acA2040-120um__23670847__20230407_144755101DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F2_acA2040-120um__23670847__20230424_142922962DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F2_acA2040-120um__23670847__20230424_142922962DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F2_acA2040-120um__23670847__20230424_142922962DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M3_acA2040-120um__23670846__20230330_110150304DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M3_acA2040-120um__23670846__20230330_110150304DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M3_acA2040-120um__23670846__20230330_110150304DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.3F2_acA2040-120um__23670847__20230324_131537513DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.3F2_acA2040-120um__23670847__20230324_131537513DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.3F2_acA2040-120um__23670847__20230324_131537513DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F1_acA2040-120um__23670847__20230413_121815375DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F1_acA2040-120um__23670847__20230413_121815375DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.2F1_acA2040-120um__23670847__20230413_121815375DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M5_acA2040-120um__23670846__20230407_123624173DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M5_acA2040-120um__23670846__20230407_123624173DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M5_acA2040-120um__23670846__20230407_123624173DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.1M4_acA2040-120um__23670847__20230417_114022419DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.1M4_acA2040-120um__23670847__20230417_114022419DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.1M4_acA2040-120um__23670847__20230417_114022419DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.1F1_acA2040-120um__23670846__20230424_114808859DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.1F1_acA2040-120um__23670846__20230424_114808859DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.1F1_acA2040-120um__23670846__20230424_114808859DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.1F3_acA2040-120um__23670846__20230424_121924485DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.1F3_acA2040-120um__23670846__20230424_121924485DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.1F3_acA2040-120um__23670846__20230424_121924485DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M2_acA2040-120um__23670847__20230330_103258091DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M2_acA2040-120um__23670847__20230330_103258091DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.1M2_acA2040-120um__23670847__20230330_103258091DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F2_acA2040-120um__23670847__20230413_135315040DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F2_acA2040-120um__23670847__20230413_135315040DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F2_acA2040-120um__23670847__20230413_135315040DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F1_acA2040-120um__23670847__20230414_121607462DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F1_acA2040-120um__23670847__20230414_121607462DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.2F1_acA2040-120um__23670847__20230414_121607462DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.3F1_acA2040-120um__23670846__20230324_130957749DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.3F1_acA2040-120um__23670846__20230324_130957749DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.3F1_acA2040-120um__23670846__20230324_130957749DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F3_acA2040-120um__23670846__20230414_114014962DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F3_acA2040-120um__23670846__20230414_114014962DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F3_acA2040-120um__23670846__20230414_114014962DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M1_acA2040-120um__23670847__20230418_120046907DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M1_acA2040-120um__23670847__20230418_120046907DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M1_acA2040-120um__23670847__20230418_120046907DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M1_acA2040-120um__23670847__20230417_121427173DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M1_acA2040-120um__23670847__20230417_121427173DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M1_acA2040-120um__23670847__20230417_121427173DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M5_acA2040-120um__23670847__20230417_131802183DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M5_acA2040-120um__23670847__20230417_131802183DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M5_acA2040-120um__23670847__20230417_131802183DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# ...
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.1F5_acA2040-120um__23670846__20230413_121401144DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.1F5_acA2040-120um__23670846__20230413_121401144DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.1F5_acA2040-120um__23670846__20230413_121401144DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.1M4_acA2040-120um__23670847__20230324_110737307DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.1M4_acA2040-120um__23670847__20230324_110737307DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.1M4_acA2040-120um__23670847__20230324_110737307DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F4_acA2040-120um__23670846__20230425_162719669DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F4_acA2040-120um__23670846__20230425_162719669DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F4_acA2040-120um__23670846__20230425_162719669DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M3_acA2040-120um__23670847__20230418_123227762DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M3_acA2040-120um__23670847__20230418_123227762DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.2M3_acA2040-120um__23670847__20230418_123227762DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.1F2_acA2040-120um__23670847__20230413_111501296DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.1F2_acA2040-120um__23670847__20230413_111501296DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.1F2_acA2040-120um__23670847__20230413_111501296DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F4_acA2040-120um__23670847__20230413_142426770DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F4_acA2040-120um__23670847__20230413_142426770DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_2.3F4_acA2040-120um__23670847__20230413_142426770DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.3F4_acA2040-120um__23670847__20230418_140641260DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.3F4_acA2040-120um__23670847__20230418_140641260DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.3F4_acA2040-120um__23670847__20230418_140641260DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M1_acA2040-120um__23670846__20230407_141224090DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M1_acA2040-120um__23670846__20230407_141224090DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M1_acA2040-120um__23670846__20230407_141224090DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_1.1M3_acA2040-120um__23670846__20230303_114219483DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_1.1M3_acA2040-120um__23670846__20230303_114219483DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_1.1M3_acA2040-120um__23670846__20230303_114219483DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M4_acA2040-120um__23670846__20230417_124200617DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M4_acA2040-120um__23670846__20230417_124200617DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.2M4_acA2040-120um__23670846__20230417_124200617DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M2_acA2040-120um__23670847__20230331_111800657DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M2_acA2040-120um__23670847__20230331_111800657DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.1M2_acA2040-120um__23670847__20230331_111800657DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_2.1F2_acA2040-120um__23670847__20230317_103235930DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_2.1F2_acA2040-120um__23670847__20230317_103235930DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_2.1F2_acA2040-120um__23670847__20230317_103235930DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.2M4_acA2040-120um__23670846__20230331_132926302DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.2M4_acA2040-120um__23670846__20230331_132926302DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_1.2M4_acA2040-120um__23670846__20230331_132926302DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F4_acA2040-120um__23670846__20230417_152052697DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F4_acA2040-120um__23670846__20230417_152052697DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Control_mMORPeYFP_SNI_3.4F4_acA2040-120um__23670846__20230417_152052697DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F2_acA2040-120um__23670847__20230414_111125869DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F2_acA2040-120um__23670847__20230414_111125869DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.1F2_acA2040-120um__23670847__20230414_111125869DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Control_mMORPeYFP_3.4F4_acA2040-120um__23670846__20230324_151506705DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Control_mMORPeYFP_3.4F4_acA2040-120um__23670846__20230324_151506705DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Control_mMORPeYFP_3.4F4_acA2040-120um__23670846__20230324_151506705DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M2_acA2040-120um__23670847__20230407_113431891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M2_acA2040-120um__23670847__20230407_113431891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.1M2_acA2040-120um__23670847__20230407_113431891DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M3_acA2040-120um__23670847__20230303_125131366DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M3_acA2040-120um__23670847__20230303_125131366DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_1.2M3_acA2040-120um__23670847__20230303_125131366DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.3F2_acA2040-120um__23670847__20230414_135211775DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.3F2_acA2040-120um__23670847__20230414_135211775DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Exp_mMORPhm4di_3W-DCZ_2.3F2_acA2040-120um__23670847__20230414_135211775DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: A_Baseline_NoSNI_Exp_mMORPhm4di_1.1M5_acA2040-120um__23670846__20230303_121426363DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for A_Baseline_NoSNI_Exp_mMORPhm4di_1.1M5_acA2040-120um__23670846__20230303_121426363DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_A_Baseline_NoSNI_Exp_mMORPhm4di_1.1M5_acA2040-120um__23670846__20230303_121426363DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M4_acA2040-120um__23670846__20230330_123620070DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M4_acA2040-120um__23670846__20230330_123620070DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_B_Baseline_SNI_Exp_mMORPhm4di_SNI_1.2M4_acA2040-120um__23670846__20230330_123620070DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.1M5_acA2040-120um__23670846__20230425_124728691DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.1M5_acA2040-120um__23670846__20230425_124728691DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.1M5_acA2040-120um__23670846__20230425_124728691DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M5_acA2040-120um__23670846__20230418_115702299DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M5_acA2040-120um__23670846__20230418_115702299DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_C_3WSNI_DCZ_Control_mMORPeYFP_3W-DCZ_3.1M5_acA2040-120um__23670846__20230418_115702299DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F4_acA2040-120um__23670847__20230424_150028285DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F4_acA2040-120um__23670847__20230424_150028285DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_2.3F4_acA2040-120um__23670847__20230424_150028285DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F3_acA2040-120um__23670847__20230425_160008571DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F3_acA2040-120um__23670847__20230425_160008571DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Control_mMORPeYFP_4W-DCZ_3.4F3_acA2040-120um__23670847__20230425_160008571DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Processing file: D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M3_acA2040-120um__23670846__20230407_144358425DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Bins: [0, 660, 1260, 1800]
# Time Labels: ['0-10 min', '11-20 min', '21-30 min']
# Saved analysis for D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M3_acA2040-120um__23670846__20230407_144358425DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/analysis_D_4WSNI_DCZ_Exp_mMORPhm4di_4W-DCZ_1.3M3_acA2040-120um__23670846__20230407_144358425DLC_resnet50_LUPE_MALEDec5shuffle1_350000.csv
# Behavior analysis completed for all files.

# %% [markdown]
# ### Cohort Comparisons

# %%
import os
import pandas as pd

# Input and output directories
input_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison'
cohort_summary_dir = f'../processed_dataset/{project_name}/figures/behavior_timepoint_comparison/cohort_summaries'
os.makedirs(cohort_summary_dir, exist_ok=True)

def aggregate_cohort_data(group_name, condition_list):
    all_metrics = []
    
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv'):
            if any(condition in file_name for condition in condition_list):
                file_path = os.path.join(input_dir, file_name)
                file_data = pd.read_csv(file_path)
                all_metrics.append(file_data)
    
    if not all_metrics:
        print(f"No matching files found for group '{group_name}' with conditions {condition_list}")
        return None
    
    combined_data = pd.concat(all_metrics, ignore_index=True)
    
    summary = combined_data.groupby(['Time Group', 'Behavior']).agg({
        'Fraction Time': ['mean', 'std'],  # Mean and standard deviation
        'Bouts per Minute': ['mean', 'std'],
        'Mean Bout Duration (s)': ['mean', 'std']
    }).reset_index()
    
    summary.columns = ['Time Group', 'Behavior', 
                       'Fraction Time (mean)', 'Fraction Time (std)',
                       'Bouts per Minute (mean)', 'Bouts per Minute (std)',
                       'Mean Bout Duration (mean)', 'Mean Bout Duration (std)']
    
    summary = summary.dropna(subset=[
        'Fraction Time (mean)', 
        'Bouts per Minute (mean)', 
        'Mean Bout Duration (mean)'
    ], how='all')
    
    return summary


for group_name in selected_groups:

    summary = aggregate_cohort_data(group_name, selected_conditions)
    if summary is not None:

        summary_file_path = os.path.join(cohort_summary_dir, f'{group_name}_cohort_summary.csv')
        summary.to_csv(summary_file_path, index=False)
        print(f"Saved cohort summary for group '{group_name}' to {summary_file_path}")

print("Cohort summaries created.")
# Out:
# Saved cohort summary for group 'A_Baseline_NoSNI' to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/cohort_summaries/A_Baseline_NoSNI_cohort_summary.csv
# Saved cohort summary for group 'B_Baseline_SNI' to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/cohort_summaries/B_Baseline_SNI_cohort_summary.csv
# Saved cohort summary for group 'C_3WSNI_DCZ' to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/cohort_summaries/C_3WSNI_DCZ_cohort_summary.csv
# Saved cohort summary for group 'D_4WSNI_DCZ' to ../processed_dataset/project_ACC_MORPDreadd_Combined/figures/behavior_timepoint_comparison/cohort_summaries/D_4WSNI_DCZ_cohort_summary.csv
# Cohort summaries created.

# %% [markdown]
# # COMPLETE
