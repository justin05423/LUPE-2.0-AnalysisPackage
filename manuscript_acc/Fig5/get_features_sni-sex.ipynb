# %%
import pickle

from tqdm import notebook
import os
import sys

if not os.path.join(os.path.abspath(''), '../') in sys.path:
    sys.path.append(os.path.join(os.path.abspath(''), '../'))
    
from utils.classification import load_data, load_features
from utils.feature_utils import feature_extraction
from utils.meta import *
import os

# %%
data_path = '../processed_dataset/raw_data_SNI_mMORp-DREADD_sex.pkl'
data = load_data(data_path)

# %% [markdown]
# ### get features from pose

# %%
if 'binned_features_SNI_mMORp-DREADD_sex.pkl' not in os.listdir('../processed_dataset/'):
    features = {key: [] for key in groups_sni_sex}
    for group in notebook.tqdm(groups_sni_sex):
        features[group] = {key: [] for key in conditions_sni_sex}
        for condition in notebook.tqdm(conditions_sni_sex):
            features[group][condition] = {key: [] for key in [f'file{i}' 
                                               for i in range(len(data[group][condition]))]}

            for i in range(len(data[group][condition])):
                features[group][condition][f'file{i}'] = (
                    feature_extraction([data[group][condition][f'file{i}']], 1, framerate=60))
else:
    features = load_features('../processed_dataset/binned_features_SNI_mMORp-DREADD_sex.pkl')
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:23<00:00, 23.66s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.29s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.55s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:22<00:00, 22.04s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.40s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.41s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.69s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.74s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.66s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:21<00:00, 21.95s/it]
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# ...

# %%
if 'binned_features_SNI_mMORp-DREADD_sex.pkl' not in os.listdir('../processed_dataset/'):
    with open('../processed_dataset/binned_features_SNI_mMORp-DREADD_sex.pkl', 'wb') as f:
        pickle.dump(features, f)
else:
    print('Binned features exists!')

# %%
features
# Out:
# {'Male': {'Control': {'file0': [array([[  9.37583029, 107.75179251,  95.42476585, ...,   9.08069787,
#              57.26527858,  51.25201003],
#            [  6.10372649,  74.08542869,  71.00186522, ..., 105.02721814,
#              50.25522803,  47.9518674 ],
#            [ 12.59744412,  20.68254777,  28.52143719, ...,  78.07385991,
#              64.99341421,  63.70824085],
#            ...,
#            [ 72.42907398,  77.05865837,  78.00243845, ...,  10.05822278,
#              15.88271259,  49.44442838],
#            [  9.10628612,  13.65918555,  11.79619422, ...,   9.31072135,
#               6.36644367,  34.51409656],
#            [  0.        ,   0.        ,   0.        , ...,   0.        ,
#               0.        ,   0.        ]])],
#    'file1': [array([[  9.77030621,  99.92885862,  89.42368877, ...,  25.14565775,
#              71.63538274,  60.17522307],
#            [  8.88358779,  46.21858967,  37.84092981, ..., 157.7799108 ,
# ...

# %%
features['Combined']['Control']['file0'][0]
# Out:
# array([[  9.37583029, 107.75179251,  95.42476585, ...,   9.08069787,
#          57.26527858,  51.25201003],
#        [  6.10372649,  74.08542869,  71.00186522, ..., 105.02721814,
#          50.25522803,  47.9518674 ],
#        [ 12.59744412,  20.68254777,  28.52143719, ...,  78.07385991,
#          64.99341421,  63.70824085],
#        ...,
#        [ 72.42907398,  77.05865837,  78.00243845, ...,  10.05822278,
#          15.88271259,  49.44442838],
#        [  9.10628612,  13.65918555,  11.79619422, ...,   9.31072135,
#           6.36644367,  34.51409656],
#        [  0.        ,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   0.        ]])
